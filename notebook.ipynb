# %% [markdown]
# # Grokking Full Experiment
#
# This notebook runs the complete multi-model grokking experiment with:
# - 4 specialist models trained on disjoint data shards
# - Weight averaging to merge specialists
# - Knowledge distillation from specialists to student
# - Baseline comparison

# %%
# Install dependencies
# !pip install torch pytorch-lightning pytorch-metrics -q

# %%
# Clone repository
# !git clone https://github.com/YazanKbaili/grok.git
# %cd grok

# %%
# Install package
# !pip install -e . -q

# %%
# Generate data
# !python scripts/make_data.py

# %%
# Run full experiment
# !python full_experiment.py --specialist_steps 50000 --final_steps 100000 --distill_steps 50000

# %%
# View results
import json
with open('logs/full_experiment/comparison_results.json') as f:
    results = json.load(f)
print(json.dumps(results, indent=2))
